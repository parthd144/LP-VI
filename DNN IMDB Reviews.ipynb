# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam

# Load IMDB dataset
max_features = 10000  # Only consider top 10,000 words
maxlen = 300          # Only consider first 300 words of each movie review

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)

# Pad sequences so that all reviews are of same length
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

# Build the model
model = Sequential()
model.add(Embedding(max_features, 32, input_length=maxlen))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=5, batch_size=512, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# --- Making Predictions on Test Data ---

# Function to decode review back to words
word_index = imdb.get_word_index()
reverse_word_index = {value: key for (key, value) in word_index.items()}

def decode_review(text_indexes):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in text_indexes])

# Predict on first 5 test reviews
predictions = model.predict(X_test[:5])

for i, pred in enumerate(predictions):
    print("\nReview:")
    print(decode_review(X_test[i]))
    print(f"\nPredicted Sentiment: {'Positive' if pred > 0.5 else 'Negative'} (Probability: {pred[0]:.4f})")
    print(f"Actual Sentiment: {'Positive' if y_test[i] == 1 else 'Negative'}")
# Out:
# Epoch 1/5
# 40/40 [==============================] - 5s 90ms/step - loss: 0.6911 - accuracy: 0.5091 - val_loss: 0.6864 - val_accuracy: 0.6768
# Epoch 2/5
# 40/40 [==============================] - 2s 58ms/step - loss: 0.6775 - accuracy: 0.7196 - val_loss: 0.6638 - val_accuracy: 0.7578
# Epoch 3/5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.6428 - accuracy: 0.7648 - val_loss: 0.6159 - val_accuracy: 0.7812
# Epoch 4/5
# 40/40 [==============================] - 2s 59ms/step - loss: 0.5821 - accuracy: 0.8099 - val_loss: 0.5487 - val_accuracy: 0.8124
# Epoch 5/5
# ...
# 782/782 [==============================] - 4s 5ms/step - loss: 0.4885 - accuracy: 0.8290
# Test Loss: 0.4885
# Test Accuracy: 0.8290
# ...
# 1/1 [==============================] - 0s 289ms/step
#
# Review:
# ...
